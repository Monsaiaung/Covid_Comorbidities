# %%
# Imports
import pandas as pd
import numpy as np
import csv
import datetime as dt

# %%
# Load in CSV files
file_path = 'Resources/Conditions_Contributing_to_COVID-19_Deaths__by_State_and_Age__Provisional_2020-2022.csv'
Covid_contributing_conditions = pd.read_csv(file_path)
Covid_contributing_conditions
# Out:
#         Data As Of  Start Date    End Date     Group    Year  Month  \
# 0       05/01/2022  01/01/2020  04/30/2022  By Total     NaN    NaN
# 1       05/01/2022  01/01/2020  04/30/2022  By Total     NaN    NaN
# 2       05/01/2022  01/01/2020  04/30/2022  By Total     NaN    NaN
# 3       05/01/2022  01/01/2020  04/30/2022  By Total     NaN    NaN
# 4       05/01/2022  01/01/2020  04/30/2022  By Total     NaN    NaN
# ...            ...         ...         ...       ...     ...    ...
# 397435  05/01/2022  12/01/2021  12/31/2021  By Month  2021.0   12.0
# 397436  05/01/2022  01/01/2022  01/31/2022  By Month  2022.0    1.0
# 397437  05/01/2022  02/01/2022  02/28/2022  By Month  2022.0    2.0
# 397438  05/01/2022  03/01/2022  03/31/2022  By Month  2022.0    3.0
# 397439  05/01/2022  04/01/2022  04/30/2022  By Month  2022.0    4.0
#
#                 State       Condition Group                Condition  \
# 0       United States  Respiratory diseases  Influenza and pneumonia
# ...

# %%
Covid_contributing_conditions.columns.tolist()
# Out:
# ['Data As Of',
#  'Start Date',
#  'End Date',
#  'Group',
#  'Year',
#  'Month',
#  'State',
#  'Condition Group',
#  'Condition',
#  'ICD10_codes',
#  'Age Group',
#  'COVID-19 Deaths',
#  'Number of Mentions',
#  'Flag']

# %%
Covid_contributing_conditions.drop(columns=['Data As Of', 'Flag'], inplace=True)

# %%
Covid_contributing_conditions.head()
# Out:
#    Start Date    End Date     Group  Year  Month          State  \
# 0  01/01/2020  04/30/2022  By Total   NaN    NaN  United States
# 1  01/01/2020  04/30/2022  By Total   NaN    NaN  United States
# 2  01/01/2020  04/30/2022  By Total   NaN    NaN  United States
# 3  01/01/2020  04/30/2022  By Total   NaN    NaN  United States
# 4  01/01/2020  04/30/2022  By Total   NaN    NaN  United States
#
#         Condition Group                Condition ICD10_codes Age Group  \
# 0  Respiratory diseases  Influenza and pneumonia     J09-J18      0-24
# 1  Respiratory diseases  Influenza and pneumonia     J09-J18     25-34
# 2  Respiratory diseases  Influenza and pneumonia     J09-J18     35-44
# 3  Respiratory diseases  Influenza and pneumonia     J09-J18     45-54
# 4  Respiratory diseases  Influenza and pneumonia     J09-J18     55-64
#
#    COVID-19 Deaths  Number of Mentions
# 0           1320.0              1380.0
# 1           5483.0              5685.0
# ...

# %%
# Selecting subset By All Age in Age Group
Covid_contributing_conditions_Allage = Covid_contributing_conditions.loc[Covid_contributing_conditions['Age Group'] == 'All Ages']
Covid_contributing_conditions_Allage
# Out:
#         Start Date    End Date     Group    Year  Month          State  \
# 9       01/01/2020  04/30/2022  By Total     NaN    NaN  United States
# 19      01/01/2020  04/30/2022  By Total     NaN    NaN  United States
# 29      01/01/2020  04/30/2022  By Total     NaN    NaN  United States
# 39      01/01/2020  04/30/2022  By Total     NaN    NaN  United States
# 49      01/01/2020  04/30/2022  By Total     NaN    NaN  United States
# ...            ...         ...       ...     ...    ...            ...
# 397435  12/01/2021  12/31/2021  By Month  2021.0   12.0    Puerto Rico
# 397436  01/01/2022  01/31/2022  By Month  2022.0    1.0    Puerto Rico
# 397437  02/01/2022  02/28/2022  By Month  2022.0    2.0    Puerto Rico
# 397438  03/01/2022  03/31/2022  By Month  2022.0    3.0    Puerto Rico
# 397439  04/01/2022  04/30/2022  By Month  2022.0    4.0    Puerto Rico
#
#              Condition Group                            Condition ICD10_codes  \
# ...

# %%
# Selecting second subset By Total in Group 
Covid_contributing_conditions_ByTotal = Covid_contributing_conditions_Allage.loc[Covid_contributing_conditions_Allage['Group'] == 'By Total']
Covid_contributing_conditions_ByTotal
# Out:
#        Start Date    End Date     Group  Year  Month          State  \
# 9      01/01/2020  04/30/2022  By Total   NaN    NaN  United States
# 19     01/01/2020  04/30/2022  By Total   NaN    NaN  United States
# 29     01/01/2020  04/30/2022  By Total   NaN    NaN  United States
# 39     01/01/2020  04/30/2022  By Total   NaN    NaN  United States
# 49     01/01/2020  04/30/2022  By Total   NaN    NaN  United States
# ...           ...         ...       ...   ...    ...            ...
# 12379  01/01/2020  04/30/2022  By Total   NaN    NaN    Puerto Rico
# 12389  01/01/2020  04/30/2022  By Total   NaN    NaN    Puerto Rico
# 12399  01/01/2020  04/30/2022  By Total   NaN    NaN    Puerto Rico
# 12409  01/01/2020  04/30/2022  By Total   NaN    NaN    Puerto Rico
# 12419  01/01/2020  04/30/2022  By Total   NaN    NaN    Puerto Rico
#
#                                          Condition Group  \
# 9                                   Respiratory diseases
# ...

# %%
# Dropping year and month
Covid_contributing_conditions_ByTotal.drop(columns=['Year','Month'], inplace=True)
Covid_contributing_conditions_ByTotal
# Out:
# C:\Users\Danie\anaconda3\anaconda\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#        Start Date    End Date     Group          State  \
# 9      01/01/2020  04/30/2022  By Total  United States
# 19     01/01/2020  04/30/2022  By Total  United States
# 29     01/01/2020  04/30/2022  By Total  United States
# 39     01/01/2020  04/30/2022  By Total  United States
# 49     01/01/2020  04/30/2022  By Total  United States
# ...           ...         ...       ...            ...
# 12379  01/01/2020  04/30/2022  By Total    Puerto Rico
# 12389  01/01/2020  04/30/2022  By Total    Puerto Rico
# 12399  01/01/2020  04/30/2022  By Total    Puerto Rico
# 12409  01/01/2020  04/30/2022  By Total    Puerto Rico
# ...

# %%
# Combining start and end date
Covid_contributing_conditions_ByTotal['Date'] = Covid_contributing_conditions_ByTotal['Start Date'] + '-' + Covid_contributing_conditions_ByTotal['End Date']
Covid_contributing_conditions_ByTotal
# Out:
# C:\Users\Danie\AppData\Local\Temp/ipykernel_20484/110615458.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Covid_contributing_conditions_ByTotal['Date'] = Covid_contributing_conditions_ByTotal['Start Date'] + '-' + Covid_contributing_conditions_ByTotal['End Date']
#        Start Date    End Date     Group          State  \
# 9      01/01/2020  04/30/2022  By Total  United States
# 19     01/01/2020  04/30/2022  By Total  United States
# 29     01/01/2020  04/30/2022  By Total  United States
# 39     01/01/2020  04/30/2022  By Total  United States
# 49     01/01/2020  04/30/2022  By Total  United States
# ...           ...         ...       ...            ...
# 12379  01/01/2020  04/30/2022  By Total    Puerto Rico
# ...

# %%
# Set Date as index, dropped start and end date
Covid_contributing_conditions_ByTotal.drop(columns=['Start Date','End Date'], inplace=True)
Covid_contributing_conditions_ByTotal.set_index('Date', drop=True, inplace=True)
Covid_contributing_conditions_ByTotal
# Out:
# C:\Users\Danie\anaconda3\anaconda\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                           Group          State  \
# Date
# 01/01/2020-04/30/2022  By Total  United States
# 01/01/2020-04/30/2022  By Total  United States
# 01/01/2020-04/30/2022  By Total  United States
# 01/01/2020-04/30/2022  By Total  United States
# 01/01/2020-04/30/2022  By Total  United States
# ...                         ...            ...
# 01/01/2020-04/30/2022  By Total    Puerto Rico
# 01/01/2020-04/30/2022  By Total    Puerto Rico
# 01/01/2020-04/30/2022  By Total    Puerto Rico
# 01/01/2020-04/30/2022  By Total    Puerto Rico
# 01/01/2020-04/30/2022  By Total    Puerto Rico
#
# ...

# %%
# Create a DataFrame object
Covid_contributing_conditions_df = pd.DataFrame(Covid_contributing_conditions_ByTotal, columns= ['Group', 'State','Condition Group', 'Condition', 'ICD10_codes', 'Age Group', 'COVID-19 Deaths', 'Number of Mentions'])

# %%
print(Covid_contributing_conditions_df)
# Out:
#                           Group          State  \
# Date
# 01/01/2020-04/30/2022  By Total  United States
# 01/01/2020-04/30/2022  By Total  United States
# 01/01/2020-04/30/2022  By Total  United States
# 01/01/2020-04/30/2022  By Total  United States
# 01/01/2020-04/30/2022  By Total  United States
# ...                         ...            ...
# 01/01/2020-04/30/2022  By Total    Puerto Rico
# 01/01/2020-04/30/2022  By Total    Puerto Rico
# 01/01/2020-04/30/2022  By Total    Puerto Rico
# 01/01/2020-04/30/2022  By Total    Puerto Rico
# 01/01/2020-04/30/2022  By Total    Puerto Rico
#
#                                                          Condition Group  \
# Date
# 01/01/2020-04/30/2022                               Respiratory diseases
# 01/01/2020-04/30/2022                               Respiratory diseases
# 01/01/2020-04/30/2022                               Respiratory diseases
# 01/01/2020-04/30/2022                               Respiratory diseases
# ...

# %%
# Export csv file
filepath = 'Resources/Covid_contributing_conditions.csv'
Covid_contributing_conditions_df.to_csv(filepath)

# %%
# Get a series of unique values in column 'Condition' of the dataframe
#uniqueValues = Covid_contributing_conditions_df['Condition Group'].unique()
#print('Unique elements in column "Condition Group" ')
#print(uniqueValues)

# %%
# Get a series of unique values in column 'Age Group' of the dataframe
#uniqueValues = Covid_contributing_conditions_df['Age Group'].unique()
#print('Unique elements in column "Age Group" ')
#print(uniqueValues)
